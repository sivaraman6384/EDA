# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\SIVARAMAN\Downloads\hospital data analysis.csv')
df
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df1=df.copy()
df1
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df1.head(10)
# Out:
#    Patient_ID  Age  Gender          Condition                  Procedure  \
# 0           1   45  Female      Heart Disease                Angioplasty
# 1           2   60    Male           Diabetes            Insulin Therapy
# 2           3   32  Female      Fractured Arm           X-Ray and Splint
# 3           4   75    Male             Stroke     CT Scan and Medication
# 4           5   50  Female             Cancer   Surgery and Chemotherapy
# 5           6   68    Male       Hypertension  Medication and Counseling
# 6           7   55  Female       Appendicitis               Appendectomy
# 7           8   40    Male      Fractured Leg  Cast and Physical Therapy
# 8           9   70  Female       Heart Attack    Cardiac Catheterization
# 9          10   25    Male  Allergic Reaction      Epinephrine Injection
#
#     Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# 0  15000               5          No  Recovered             4
# ...

# %%
df1.tail(10)
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 974         991   48  Female      Heart Disease                Angioplasty
# 975         992   65    Male           Diabetes            Insulin Therapy
# 976         993   30  Female      Fractured Arm           X-Ray and Splint
# 977         994   70    Male             Stroke     CT Scan and Medication
# 978         995   55  Female             Cancer   Surgery and Chemotherapy
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# 974  15000              71         Yes  Recovered             4
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      984 non-null    int64
#  1   Age             984 non-null    int64
#  2   Gender          984 non-null    object
#  3   Condition       984 non-null    object
#  4   Procedure       984 non-null    object
#  5   Cost            984 non-null    int64
#  6   Length_of_Stay  984 non-null    int64
#  7   Readmission     984 non-null    object
#  8   Outcome         984 non-null    object
#  9   Satisfaction    984 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 77.0+ KB

# %%
df1.describe()
# Out:
#         Patient_ID         Age          Cost  Length_of_Stay  Satisfaction
# count   984.000000  984.000000    984.000000      984.000000    984.000000
# mean    500.329268   53.754065   8367.479675       37.663618      3.598577
# std     288.979531   14.941135   7761.990976       19.595805      0.883002
# min       1.000000   25.000000    100.000000        1.000000      2.000000
# 25%     250.750000   45.000000   1000.000000       21.000000      3.000000
# 50%     500.500000   55.000000   6000.000000       38.000000      4.000000
# 75%     750.250000   65.000000  15000.000000       54.250000      4.000000
# max    1000.000000   78.000000  25000.000000       76.000000      5.000000

# %%
missing_valu=df1.isnull().sum()
missing_valu
# Out:
# Patient_ID        0
# Age               0
# Gender            0
# Condition         0
# Procedure         0
# Cost              0
# Length_of_Stay    0
# Readmission       0
# Outcome           0
# Satisfaction      0
# dtype: int64

# %%
df1.describe()
# Out:
#         Patient_ID         Age          Cost  Length_of_Stay  Satisfaction
# count   984.000000  984.000000    984.000000      984.000000    984.000000
# mean    500.329268   53.754065   8367.479675       37.663618      3.598577
# std     288.979531   14.941135   7761.990976       19.595805      0.883002
# min       1.000000   25.000000    100.000000        1.000000      2.000000
# 25%     250.750000   45.000000   1000.000000       21.000000      3.000000
# 50%     500.500000   55.000000   6000.000000       38.000000      4.000000
# 75%     750.250000   65.000000  15000.000000       54.250000      4.000000
# max    1000.000000   78.000000  25000.000000       76.000000      5.000000

# %%
df1.rename(columns={'Satisfaction':'Patient_Satisfaction'},inplace=True)
df1
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
# ...

# %%
df1.rename(columns={'Outcome':'health_status'},inplace=True)
df1
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
# ...

# %%
df1.rename(columns={'Condition':'Patient_Condition'},inplace=True)
df1
# Out:
#      Patient_ID  Age  Gender  Patient_Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
# ...

# %%
df_row=df1[(df1['Length_of_Stay']>10)].head(15)
df_row
# Out:
#     Patient_ID  Age  Gender Patient_Condition                  Procedure  \
# 19          20   53  Female            Cancer   Surgery and Chemotherapy
# 34          35   55  Female            Cancer   Surgery and Chemotherapy
# 41          42   58    Male   Prostate Cancer          Radiation Therapy
# 49          50   53  Female            Cancer   Surgery and Chemotherapy
# 53          54   75  Female      Heart Attack    Cardiac Catheterization
# 56          57   67    Male   Prostate Cancer          Radiation Therapy
# 62          64   70    Male            Stroke     CT Scan and Medication
# 63          65   55  Female            Cancer   Surgery and Chemotherapy
# 67          69   78  Female      Heart Attack    Cardiac Catheterization
# 70          72   58    Male   Prostate Cancer          Radiation Therapy
# 77          79   78    Male            Stroke     CT Scan and Medication
# 78          80   53  Female            Cancer   Surgery and Chemotherapy
# ...

# %%
df1['complicated'] = np.where((df1['Age']>60) & (df1['Length_of_Stay']>5), 'yes', 'No')
df1
/
# Out:
# ()

# %%
df1
# Out:
#      Patient_ID  Age  Gender  Patient_Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
# ...

# %%
plt.hist(df1['Age'],color='#9BA2FF',edgecolor='#0F0F0F')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Histogram of age')
plt.show()

# %%
df1['Gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
Q1 = df1['Cost'].quantile(0.25)
Q3 = df1['Cost'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 14000.0

# %%
lower_bound1=Q1 - 1.5 * IQR
lower_bound1
# Out:
# -20000.0

# %%
upper_bound1=Q3+1.5*IQR
upper_bound1
# Out:
# 36000.0

# %%
df1.boxplot(column='Cost')
plt.title('Cost Distribution')
plt.ylabel('Cost')
plt.show()

# %%
plt.hist(df1['Cost'],color='#9BA2FF',edgecolor='#0F0F0F')
plt.xlabel('cost Amount')
plt.ylabel('Frequency')
plt.title('Histogram of cost')
plt.show()

# %%
df1['Age'].plot(kind='kde')
plt.title('Age Density Plot')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(x='Cost',y='Length_of_Stay',hue='Gender',data=df1,palette='bright',style='Gender',markers=['o','s'])
plt.title('scatterplot:total bill vs tip')
plt.xlabel('cost')
plt.ylabel('Length_of_Stay')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='health_status', y='Age', data=df1)
plt.title('health by age')
# Out:
# Text(0.5, 1.0, 'health by age')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Cost', data=df1)
plt.title('gender by age')
# Out:
# Text(0.5, 1.0, 'gender by age')

# %%
patient_state=df1['Patient_Condition'].value_counts()
plt.figure(figsize=(10,10))
plt.pie(patient_state,labels=patient_state.index,autopct='%1.1f%%',startangle=90,)
plt.title('various condition of the patient')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='complicated', y='Length_of_Stay', data=df1)
plt.title('complicated by length of stay')
# Out:
# Text(0.5, 1.0, 'complicated by length of stay')

# %%
hm=50

# %%
t_stat,p_value=ttest_1samp(df1['Age'],hm)
alpha=0.05

print(f"T-statistic:{t_stat}")
print(f"p-value:{p_value}")

if p_value<alpha:
    print(f"reject the null hypothesis at alpha={alpha}")
else:
    print(f"fail to reject the null hypothesis at alpha={alpha}")
# Out:
# T-statistic:7.881624601035427
# p-value:8.544537379443802e-15
# reject the null hypothesis at alpha=0.05
